# %%
# !git clone https://github.com/blancsw/deep_4_all.git
# !pip install "accelerate>=1.12.0" "bitsandbytes>=0.49.1" "datasets>=4.5.0" "matplotlib>=3.10.8" "pandas>=2.3.3" "plotly>=6.5.2" "scikit-learn>=1.8.0" "sentencepiece>=0.2.1" "transformers>=4.57.5"
# Out:
# Cloning into 'deep_4_all'...
# remote: Enumerating objects: 878, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 878 (delta 14), reused 12 (delta 12), pack-reused 851 (from 1)
# Receiving objects: 100% (878/878), 196.80 MiB | 25.60 MiB/s, done.
# Resolving deltas: 100% (398/398), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.2/515.2 kB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 88.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 90.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 100.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Copy the folder from your local Colab environment to your Google Drive
# !cp -r deep_4_all /content/gdrive/MyDrive/

# %%
# %cd /content/gdrive/MyDrive/deep_4_all/cours/TP/tp2/
# !python train_dungeon_logs.py
# Out:
# /content/gdrive/MyDrive/deep_4_all/cours/TP/tp2
# ...
# ORACLE DU DONJON - Entraînement
# ...
#
# Configuration:
# ----------------------------------------
#   embed_dim: 258
#   hidden_dim: 258
#   num_layers: 1
#   dropout: 0.0
#   mode: linear
#   bidirectional: False
#   epochs: 6
#   batch_size: 32
#   learning_rate: 0.1
#   optimizer: sgd
#   weight_decay: 0.0
#   use_scheduler: False
#   early_stopping: False
#   patience: 10
#   plot: True
# ----------------------------------------
# Device: cpu
# Chargement des données...
# Train: 14000 séquences
# Val: 3000 séquences
# Vocabulaire: 45 tokens
# Longueur des séquences: min=2, max=109, mean=34.6
#
# Création du modèle...
# Architecture: linear
# Bidirectionnel: False
# Paramètres: 9,397,909
# Optimiseur: SGD, LR: 0.1
#
# ...
# Début de l'entraînement
# ...
